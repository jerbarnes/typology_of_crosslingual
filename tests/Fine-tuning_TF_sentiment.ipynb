# %%
from transformers import TFBertForSequenceClassification, BertTokenizer
import tensorflow as tf
import pandas as pd
from data_preparation import Example, convert_examples_to_tf_dataset

# %%
model = TFBertForSequenceClassification.from_pretrained('bert-base-multilingual-cased')
model.bert.trainable = False
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing TFBertForSequenceClassification: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['dropout_37', 'classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy()
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

# %%
train = pd.read_csv("../data/sentiment/en/train.csv", header=None)
train.columns = ["sentiment", "review"]
dev = pd.read_csv("../data/sentiment/en/dev.csv", header=None)
dev.columns = ["sentiment", "review"]
test = pd.read_csv("../data/sentiment/en/test.csv", header=None)
test.columns = ["sentiment", "review"]

# %%
train.head()
# Out:
#    sentiment                                             review
# 0          1  The Rock is destined to be the st Century 's n...
# 1          1  The gorgeously elaborate continuation of `` Th...
# 2          1  Singer\/composer Bryan Adams contributes a sle...
# 3          1               Yet the act is still charming here .
# 4          1  Whether or not you 're enlightened by any of D...

# %% [markdown]
# Longest sequence

# %%
train["review"].apply(lambda x: len(tokenizer(x)["input_ids"])).max()
# Out:
# 88

# %%
train_dataset = convert_examples_to_tf_dataset([(Example(text=text, category_index=label)) for label, text in train.values], 
                                               tokenizer, max_length=128)
dev_dataset = convert_examples_to_tf_dataset([(Example(text=text, category_index=label)) for label, text in dev.values], 
                                             tokenizer, max_length=128)
test_dataset = convert_examples_to_tf_dataset([(Example(text=text, category_index=label)) for label, text in test.values], 
                                              tokenizer, max_length=128)
# Out:
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %%
train_batches = len(list(iter(train_dataset.shuffle(10000).batch(32))))
print("Train batches: ", train_batches)
train_dataset = train_dataset.shuffle(10000).batch(32).repeat(5)

dev_batches = len(list(iter(dev_dataset.shuffle(10000).batch(32))))
print("Dev batches: ", dev_batches)
dev_dataset = dev_dataset.shuffle(10000).batch(32).repeat(5)

test_batches = len(list(iter(test_dataset.shuffle(10000).batch(32))))
print("Test batches: ", test_batches)
test_dataset = test_dataset.shuffle(10000).batch(32)
# Out:
# Train batches:  217
# Dev batches:  28
# Test batches:  57

# %%
model.fit(train_dataset, epochs=5, steps_per_epoch=train_batches, validation_data=dev_dataset, validation_steps=dev_batches)
# Out:
# Epoch 1/5
# 217/217 [==============================] - 76s 350ms/step - loss: 0.6951 - sparse_categorical_accuracy: 0.5051 - val_loss: 0.6916 - val_sparse_categorical_accuracy: 0.5149
# Epoch 2/5
# 217/217 [==============================] - 79s 363ms/step - loss: 0.6936 - sparse_categorical_accuracy: 0.5092 - val_loss: 0.6892 - val_sparse_categorical_accuracy: 0.5149
# Epoch 3/5
# 217/217 [==============================] - 78s 360ms/step - loss: 0.6916 - sparse_categorical_accuracy: 0.5212 - val_loss: 0.6864 - val_sparse_categorical_accuracy: 0.5161
# Epoch 4/5
# 217/217 [==============================] - 78s 360ms/step - loss: 0.6893 - sparse_categorical_accuracy: 0.5396 - val_loss: 0.6836 - val_sparse_categorical_accuracy: 0.5321
# Epoch 5/5
# 217/217 [==============================] - 78s 361ms/step - loss: 0.6865 - sparse_categorical_accuracy: 0.5461 - val_loss: 0.6807 - val_sparse_categorical_accuracy: 0.5872
